# %% [markdown]
# # ITMGT 25.03 EE
# # Assignment 3B
#
# This is a data-cleaning assignment and is the second of two parts. This notebook is uploaded to our Github repository along with a csv of fake, dirty data called **recweekdata.csv**.
#
# In addition, you have a new file called **studentprofiles.csv** which has first and last names plus the genders of the students.
#
# The output of this assignment is to convert recweekdata.csv into processable data for statistics. Submit the following files through GitHub:
# 1. A cleaned recweekdata.csv called **cleanrecweekdata3b.csv** **(5 points)**
# 2. This notebook, containing the code (properly commented) that you used to clean the data **(5 points)**
# 3. An html file of summary statistics from each column called **stats3b.html**. The requirements for the summary statistics are described below. **(10 points)**
#
# The outputs are similar to that of Assignment 3A, except that you will now use Pandas instead of Python lists.
#
# This entire assignment (3B) is worth 20 points.
#
# Upload your output files to your Github repositories. Make sure to send an email to **joben.ilagan@gmail.com** once you're done.
#
# This assignment is due on **Monday, July 9, 2019** at 12:00NN.
#
# Note: I understand you all need to review for LT 2. Think of this Assignment as practice. It's not meant to take you as long as 3A.
#
# #### Bonus Points:
# * +2 if submitted over (or before) the weekend (July 13-14)
# * +2 if CSS and div tags are used (but please don't spend too much time on this because you still need to review for the Long Test)

# %%
## Code goes here
import pandas as pd
import numpy as np
import re

# %%
df1=pd.read_csv("recweekdata.csv")

# %%
df1
# Out:
#      firstname      lastname birthmonth  birthday  birthyear  \
# 0        name1     lastname1         11        26       1998
# 1        name2     lastname2        May        26       2001
# 2        name3     lastname3          5        16       1997
# 3        name4     lastname4        Dec         9         97
# 4        name5     lastname5        Sep         5         97
# 5        name6     lastname6      March         2       1999
# 6        name7     lastname7         11        10         98
# 7        name8     lastname8        Aug        28         99
# 8        name9     lastname9       July        10         97
# 9       name10    lastname10          9        14       2001
# 10      name11    lastname11   December         8         98
# 11      name12    lastname12          5         4         97
# 12      name13    lastname13    January        28       1999
# 13      name14    lastname14          1        11       1999
# ...

# %%
# cleaning the birthmonth

df1.loc[:,"birthmonth"].replace("^January","1",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^February","2",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^March","3",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^April","4",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^May","5",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^June","6",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^July","7",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^August","8",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^September","9",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^October","10",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^November","11",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^December","12",regex=True,inplace=True)

df1.loc[:,"birthmonth"].replace("^Jan","1",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Feb","2",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Mar","3",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Apr","4",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^May","5",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Jun","6",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Jul","7",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Aug","8",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Sep","9",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Oct","10",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Nov","11",regex=True,inplace=True)
df1.loc[:,"birthmonth"].replace("^Dec","12",regex=True,inplace=True)

# %%
df1
# Out:
#      firstname      lastname birthmonth  birthday  birthyear  \
# 0        name1     lastname1         11        26       1998
# 1        name2     lastname2          5        26       2001
# 2        name3     lastname3          5        16       1997
# 3        name4     lastname4         12         9         97
# 4        name5     lastname5          9         5         97
# 5        name6     lastname6          3         2       1999
# 6        name7     lastname7         11        10         98
# 7        name8     lastname8          8        28         99
# 8        name9     lastname9          7        10         97
# 9       name10    lastname10          9        14       2001
# 10      name11    lastname11         12         8         98
# 11      name12    lastname12          5         4         97
# 12      name13    lastname13          1        28       1999
# 13      name14    lastname14          1        11       1999
# ...

# %%
#cleaning of birth year

df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^97","1997", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^98","1998", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^99","1999", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^00","2000", regex = True)
df1.loc[:,"birthyear"] = df1.loc[:,"birthyear"].astype(str).replace("^01","2001", regex = True)

# %%
df1
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1         11        26      1998
# 1        name2     lastname2          5        26      2001
# 2        name3     lastname3          5        16      1997
# 3        name4     lastname4         12         9      1997
# 4        name5     lastname5          9         5      1997
# 5        name6     lastname6          3         2      1999
# 6        name7     lastname7         11        10      1998
# 7        name8     lastname8          8        28      1999
# 8        name9     lastname9          7        10      1997
# 9       name10    lastname10          9        14      2001
# 10      name11    lastname11         12         8      1998
# 11      name12    lastname12          5         4      1997
# 12      name13    lastname13          1        28      1999
# 13      name14    lastname14          1        11      1999
# 14      name15    lastname15          6         6      1998
# ...

# %%
#cleaning of course

df1.loc[:,"course"].replace(r"^LM","BS Legal Management",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^ITE","BS Information Technology Entrepreneurship",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^MGT","BS Management",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^CTM","BS Communications Technology",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^ME","BS Management Engineering",regex=True,inplace=True)

df1.loc[:,"course"].replace(r"^BS LM","BS Legal Management",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^BS ITE","BS Information Technology Entrepreneurship",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^BS MGT","BS Management",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^BS CTM","BS Communications Technology",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^BS ME","BS Management Engineering",regex=True,inplace=True)

df1.loc[:,"course"].replace(r"^Legal Management","BS Legal Management",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^Information Technology Entrepreneurship","BS Information Technology Entrepreneurship",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^Management","BS Management",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^Communications Technology","BS Communications Technology",regex=True,inplace=True)
df1.loc[:,"course"].replace(r"^Management Engineering","BS Management Engineering",regex=True,inplace=True)

# %%
df1
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1         11        26      1998
# 1        name2     lastname2          5        26      2001
# 2        name3     lastname3          5        16      1997
# 3        name4     lastname4         12         9      1997
# 4        name5     lastname5          9         5      1997
# 5        name6     lastname6          3         2      1999
# 6        name7     lastname7         11        10      1998
# 7        name8     lastname8          8        28      1999
# 8        name9     lastname9          7        10      1997
# 9       name10    lastname10          9        14      2001
# 10      name11    lastname11         12         8      1998
# 11      name12    lastname12          5         4      1997
# 12      name13    lastname13          1        28      1999
# 13      name14    lastname14          1        11      1999
# 14      name15    lastname15          6         6      1998
# ...

# %%
df1.loc[:,"phonenumber"] = df1.loc[:,"phonenumber"].replace("^9","+63 9", regex = True)

# %%
df1
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1         11        26      1998
# 1        name2     lastname2          5        26      2001
# 2        name3     lastname3          5        16      1997
# 3        name4     lastname4         12         9      1997
# 4        name5     lastname5          9         5      1997
# 5        name6     lastname6          3         2      1999
# 6        name7     lastname7         11        10      1998
# 7        name8     lastname8          8        28      1999
# 8        name9     lastname9          7        10      1997
# 9       name10    lastname10          9        14      2001
# 10      name11    lastname11         12         8      1998
# 11      name12    lastname12          5         4      1997
# 12      name13    lastname13          1        28      1999
# 13      name14    lastname14          1        11      1999
# 14      name15    lastname15          6         6      1998
# ...

# %%
carrier = {"+63 917":"Globe","+63 918":"Smart", "+63 927":"Globe"}

# %%
df1.loc[:,"phonenumber"].str[0:7].apply(lambda x: carrier[x])
# Out:
# 0       Smart
# 1       Globe
# 2       Smart
# 3       Smart
# 4       Globe
# 5       Smart
# 6       Globe
# 7       Globe
# 8       Smart
# 9       Smart
# 10      Globe
# 11      Globe
# 12      Globe
# 13      Globe
# 14      Globe
# 15      Smart
# 16      Globe
# 17      Globe
# 18      Globe
# 19      Globe
# 20      Globe
# 21      Globe
# 22      Globe
# 23      Globe
# 24      Smart
# 25      Globe
# 26      Globe
# 27      Globe
# 28      Globe
# 29      Globe
#         ...
# 2970    Smart
# 2971    Globe
# 2972    Globe
# 2973    Globe
# 2974    Globe
# 2975    Globe
# 2976    Smart
# 2977    Smart
# 2978    Smart
# 2979    Smart
# 2980    Globe
# 2981    Globe
# 2982    Smart
# 2983    Globe
# 2984    Globe
# 2985    Globe
# 2986    Smart
# 2987    Globe
# 2988    Globe
# 2989    Globe
# 2990    Smart
# 2991    Globe
# 2992    Globe
# 2993    Globe
# 2994    Globe
# 2995    Globe
# 2996    Globe
# 2997    Globe
# 2998    Globe
# 2999    Smart
# ...

# %%
df1["carrier"] = df1.loc[:,"phonenumber"].str[0:7].apply(lambda x: carrier[x])

# %%
df1
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1         11        26      1998
# 1        name2     lastname2          5        26      2001
# 2        name3     lastname3          5        16      1997
# 3        name4     lastname4         12         9      1997
# 4        name5     lastname5          9         5      1997
# 5        name6     lastname6          3         2      1999
# 6        name7     lastname7         11        10      1998
# 7        name8     lastname8          8        28      1999
# 8        name9     lastname9          7        10      1997
# 9       name10    lastname10          9        14      2001
# 10      name11    lastname11         12         8      1998
# 11      name12    lastname12          5         4      1997
# 12      name13    lastname13          1        28      1999
# 13      name14    lastname14          1        11      1999
# 14      name15    lastname15          6         6      1998
# ...

# %%
df1.to_csv("cleaneddf1.csv")

# %%
cleaneddf1=pd.read_csv("cleaneddf1.csv")

# %%
df2=pd.read_csv("studentprofiles.csv")

# %%
df2
# Out:
#      firstname      lastname  gender
# 0        name1     lastname1  Female
# 1        name2     lastname2  Female
# 2        name3     lastname3  Female
# 3        name4     lastname4    Male
# 4        name5     lastname5  Female
# 5        name6     lastname6  Female
# 6        name7     lastname7  Female
# 7        name8     lastname8    Male
# 8        name9     lastname9    Male
# 9       name10    lastname10  Female
# 10      name11    lastname11    Male
# 11      name12    lastname12    Male
# 12      name13    lastname13  Female
# 13      name14    lastname14  Female
# 14      name15    lastname15    Male
# 15      name16    lastname16    Male
# 16      name17    lastname17  Female
# 17      name18    lastname18  Female
# 18      name19    lastname19    Male
# 19      name20    lastname20    Male
# 20      name21    lastname21  Female
# 21      name22    lastname22    Male
# 22      name23    lastname23    Male
# 23      name24    lastname24    Male
# ...

# %%
pd.merge(df1, df2, how="left",left_on=["firstname","lastname"], right_on=["firstname","lastname"])
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1         11        26      1998
# 1        name2     lastname2          5        26      2001
# 2        name3     lastname3          5        16      1997
# 3        name4     lastname4         12         9      1997
# 4        name5     lastname5          9         5      1997
# 5        name6     lastname6          3         2      1999
# 6        name7     lastname7         11        10      1998
# 7        name8     lastname8          8        28      1999
# 8        name9     lastname9          7        10      1997
# 9       name10    lastname10          9        14      2001
# 10      name11    lastname11         12         8      1998
# 11      name12    lastname12          5         4      1997
# 12      name13    lastname13          1        28      1999
# 13      name14    lastname14          1        11      1999
# 14      name15    lastname15          6         6      1998
# ...

# %%
merged_df=pd.merge(cleaneddf1, df2, how="left",left_on=["firstname","lastname"], right_on=["firstname","lastname"])

# %%
merged_df
# Out:
#       Unnamed: 0 firstname      lastname  birthmonth  birthday  birthyear  \
# 0              0     name1     lastname1          11        26       1998
# 1              1     name2     lastname2           5        26       2001
# 2              2     name3     lastname3           5        16       1997
# 3              3     name4     lastname4          12         9       1997
# 4              4     name5     lastname5           9         5       1997
# 5              5     name6     lastname6           3         2       1999
# 6              6     name7     lastname7          11        10       1998
# 7              7     name8     lastname8           8        28       1999
# 8              8     name9     lastname9           7        10       1997
# 9              9    name10    lastname10           9        14       2001
# 10            10    name11    lastname11          12         8       1998
# 11            11    name12    lastname12           5         4       1997
# ...

# %%
merged_df.groupby(["birthmonth"])['firstname'].count()
# Out:
# birthmonth
# 1     270
# 2     232
# 3     246
# 4     267
# 5     273
# 6     259
# 7     249
# 8     241
# 9     232
# 10    178
# 11    277
# 12    276
# Name: firstname, dtype: int64

# %% [markdown]
# # Required Summary Statistics
#
# #### These were the questions from 3A:
#
# 1. How many people were born in each month?
# 2. How many people were born on each day?
# 3. How many people were born in each year?
# 4. How many people come from each course?
# 5. How many people have numbers from Globe (0917 or 0927) and Smart (0918)? *Note: it's up to you how to format this output*
#
# #### Additional Questions:
# * How many Globe subscribers are: Male? Female?
# * How many Smart subscribers are: Male? Female?
#
# Answer these questions in an html file called **stats3b.html**. The format of the html is as follows (in template form, so you can use this as format string in your program, though feel free to modify with variable names if you find it easier to do so):

# %% [markdown]
# ```
# <html>
#     <body>
#          <h2>Summary Statistics</h2>
#          <table>
#              <tr><th>Stat</th><th>Value</th></tr>
#              <tr><td>People born in each month</td><td>{}</td></tr>
#              <tr><td>People born on each day</td><td>{}</td></tr>
#              <tr><td>People born in each year</td><td>{}</td></tr>
#              <tr><td>People coming from each course</td><td>{}</td></tr>
#              <tr><td>People having numbers from Globe and Smart</td><td>{}</td></tr>
#              <tr><td>Male Globe subscribers:</td><td>{}</td></tr>
#              <tr><td>Female Globe subscribers:</td><td>{}</td></tr>
#              <tr><td>Male Smart subscribers:</td><td>{}</td></tr>
#              <tr><td>Female Smart subscribers:</td><td>{}</td></tr>
#          </table>
#     </body>
# </html>
# ```

# %%
merged_df.groupby(["lastname","birthmonth"])['firstname'].count()
# Out:
# lastname      birthmonth
# lastname1     11            1
# lastname10    9             1
# lastname100   5             1
# lastname1000  7             1
# lastname1001  10            1
# lastname1002  1             1
# lastname1003  7             1
# lastname1004  6             1
# lastname1005  1             1
# lastname1006  3             1
# lastname1007  9             1
# lastname1008  5             1
# lastname1009  2             1
# lastname101   4             1
# lastname1010  5             1
# lastname1011  4             1
# lastname1012  5             1
# lastname1013  9             1
# lastname1014  5             1
# lastname1015  3             1
# lastname1016  4             1
# lastname1017  1             1
# lastname1018  2             1
# lastname1019  7             1
# lastname102   8             1
# lastname1020  3             1
# lastname1021  5             1
# lastname1022  12            1
# lastname1023  6             1
# lastname1024  9             1
# ...

# %%
birthmonthcount=merged_df.groupby(["lastname","birthmonth"])['firstname'].count()

birthmonthcount
# Out:
# lastname      birthmonth
# lastname1     11            1
# lastname10    9             1
# lastname100   5             1
# lastname1000  7             1
# lastname1001  10            1
# lastname1002  1             1
# lastname1003  7             1
# lastname1004  6             1
# lastname1005  1             1
# lastname1006  3             1
# lastname1007  9             1
# lastname1008  5             1
# lastname1009  2             1
# lastname101   4             1
# lastname1010  5             1
# lastname1011  4             1
# lastname1012  5             1
# lastname1013  9             1
# lastname1014  5             1
# lastname1015  3             1
# lastname1016  4             1
# lastname1017  1             1
# lastname1018  2             1
# lastname1019  7             1
# lastname102   8             1
# lastname1020  3             1
# lastname1021  5             1
# lastname1022  12            1
# lastname1023  6             1
# lastname1024  9             1
# ...

# %%
janaury = birthmonthcount.count('birthmonth')[1]
february = birthmonthcount.count('birthmonth')[2]
march = birthmonthcount.count('birthmonth')[3]
april = birthmonthcount.count('birthmonth')[4]
may = birthmonthcount.count('birthmonth')[5]
june = birthmonthcount.count('birthmonth')[6]
july = birthmonthcount.count('birthmonth')[7]
august = birthmonthcount.count('birthmonth')[8]
september = birthmonthcount.count('birthmonth')[9]
october = birthmonthcount.count('birthmonth')[10]
november = birthmonthcount.count('birthmonth')[11]
december = birthmonthcount.count('birthmonth')[12]

# %%
merged_df.groupby(["lastname","birthday"])['firstname'].count()
# Out:
# lastname      birthday
# lastname1     26          1
# lastname10    14          1
# lastname100   10          1
# lastname1000  24          1
# lastname1001  13          1
# lastname1002  16          1
# lastname1003  1           1
# lastname1004  8           1
# lastname1005  14          1
# lastname1006  23          1
# lastname1007  14          1
# lastname1008  13          1
# lastname1009  23          1
# lastname101   2           1
# lastname1010  25          1
# lastname1011  9           1
# lastname1012  14          1
# lastname1013  8           1
# lastname1014  1           1
# lastname1015  10          1
# lastname1016  16          1
# lastname1017  17          1
# lastname1018  21          1
# lastname1019  16          1
# lastname102   14          1
# lastname1020  13          1
# lastname1021  20          1
# lastname1022  4           1
# lastname1023  28          1
# lastname1024  9           1
#                          ..
# lastname972   28          1
# ...

# %%
birthdaycount=merged_df.groupby(["lastname","birthday"])['firstname'].count()

# %%
d1=birthdaycount.count("birthday")[1]
d2=birthdaycount.count("birthday")[2]
d3=birthdaycount.count("birthday")[3]
d4=birthdaycount.count("birthday")[4]
d5=birthdaycount.count("birthday")[5]
d6=birthdaycount.count("birthday")[6]
d7=birthdaycount.count("birthday")[7]
d8=birthdaycount.count("birthday")[8]
d9=birthdaycount.count("birthday")[9]
d10=birthdaycount.count("birthday")[10]
d11=birthdaycount.count("birthday")[11]
d12=birthdaycount.count("birthday")[12]
d13=birthdaycount.count("birthday")[13]
d14=birthdaycount.count("birthday")[14]
d15=birthdaycount.count("birthday")[15]
d16=birthdaycount.count("birthday")[16]
d17=birthdaycount.count("birthday")[17]
d18=birthdaycount.count("birthday")[18]
d19=birthdaycount.count("birthday")[19]
d20=birthdaycount.count("birthday")[20]
d21=birthdaycount.count("birthday")[21]
d22=birthdaycount.count("birthday")[22]
d23=birthdaycount.count("birthday")[23]
d24=birthdaycount.count("birthday")[24]
d25=birthdaycount.count("birthday")[25]
d26=birthdaycount.count("birthday")[26]
d27=birthdaycount.count("birthday")[27]
d28=birthdaycount.count("birthday")[28]

# %%
merged_df.groupby(["lastname","birthyear"])['firstname'].count()
# Out:
# lastname      birthyear
# lastname1     1998         1
# lastname10    2001         1
# lastname100   1999         1
# lastname1000  1998         1
# lastname1001  1999         1
# lastname1002  1997         1
# lastname1003  1999         1
# lastname1004  1997         1
# lastname1005  2000         1
# lastname1006  1999         1
# lastname1007  1997         1
# lastname1008  1998         1
# lastname1009  1998         1
# lastname101   1997         1
# lastname1010  1999         1
# lastname1011  1999         1
# lastname1012  1997         1
# lastname1013  1997         1
# lastname1014  2001         1
# lastname1015  1997         1
# lastname1016  1997         1
# lastname1017  1998         1
# lastname1018  1997         1
# lastname1019  2001         1
# lastname102   2001         1
# lastname1020  1999         1
# lastname1021  1998         1
# lastname1022  1997         1
# lastname1023  2000         1
# lastname1024  1998         1
#                           ..
# ...

# %%
birthyearcount=merged_df.groupby(["lastname","birthyear"])['firstname'].count()

# %%
y1997=birthyearcount.count('birthyear')[1997]
y1998=birthyearcount.count('birthyear')[1998]
y1999=birthyearcount.count('birthyear')[1999]
y2000=birthyearcount.count('birthyear')[2000]
y2001=birthyearcount.count('birthyear')[2001]

# %%
merged_df.groupby(["lastname","course"])['firstname'].count()
# Out:
# lastname      course
# lastname1     BS Legal Management                           1
# lastname10    BS Communications Technology                  1
# lastname100   BS Management                                 1
# lastname1000  BS Legal Management                           1
# lastname1001  BS Legal Management                           1
# lastname1002  BS Information Technology Entrepreneurship    1
# lastname1003  BS Information Technology Entrepreneurship    1
# lastname1004  BS Management Engineering                     1
# lastname1005  BS Management                                 1
# lastname1006  BS Information Technology Entrepreneurship    1
# lastname1007  BS Management                                 1
# lastname1008  BS Communications Technology                  1
# lastname1009  BS Management                                 1
# lastname101   BS Communications Technology                  1
# lastname1010  BS Management                                 1
# ...

# %%
coursecount=merged_df.groupby(["lastname","course"])['firstname'].count()

# %%
lm=coursecount.count('course')["BS Legal Management"]
ite=coursecount.count('course')["BS Information Technology Entrepreneurship"]
mgt=coursecount.count('course')["BS Management"]
ctm=coursecount.count('course')["BS Communications Technology"]
me=coursecount.count('course')["BS Management Engineering"]

# %%
merged_df.groupby(["gender","carrier"])['phonenumber'].count()
# Out:
# gender  carrier
# Female  Globe       984
#         Smart       494
# Male    Globe      1061
#         Smart       461
# Name: phonenumber, dtype: int64

# %%
carriercount=merged_df.groupby(["gender","carrier"])['phonenumber'].count()

# %%
globe=carriercount.count('carrier')["Globe"]
smart=carriercount.count('carrier')["Smart"]

# %%
merged_df.groupby(["gender","carrier"])['firstname'].count()
# Out:
# gender  carrier
# Female  Globe       984
#         Smart       494
# Male    Globe      1061
#         Smart       461
# Name: firstname, dtype: int64

# %%
carriergendercount=merged_df.groupby(["gender","carrier"])['firstname'].count()

# %%
Mglobe=carriergendercount[('Male','Globe')]
Fglobe=carriergendercount[('Female','Globe')]
Msmart=carriergendercount[('Male','Smart')]
Fsmart=carriergendercount[('Female','Smart')]

# %%
from IPython.core.display import HTML

html = """
<p>Summary Statistics</p>
<table style="width: 650px;">
<tbody>
<tr style="height: 103px;">
<td style="width: 89px; height: 103px;">Number of People Born in Each Month</td>
<td style="width: 43px; height: 103px;">&nbsp;Jan</td>
<td style="width: 43px; height: 103px;">&nbsp;Feb</td>
<td style="width: 43px; height: 103px;">&nbsp;March</td>
<td style="width: 43px; height: 103px;">&nbsp;April</td>
<td style="width: 43px; height: 103px;">&nbsp;May</td>
<td style="width: 15px; height: 103px;">&nbsp;June</td>
<td style="width: 15px; height: 103px;">&nbsp;July</td>
<td style="width: 15px; height: 103px;">Aug&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;Sept</td>
<td style="width: 15px; height: 103px;">&nbsp;Oct</td>
<td style="width: 15px; height: 103px;">Nov</td>
<td style="width: 15px; height: 103px;">Dec</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
<td style="width: 15px; height: 103px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;{january}</td>
<td style="width: 43px; height: 23px;">&nbsp;{february}</td>
<td style="width: 43px; height: 23px;">&nbsp;{march}</td>
<td style="width: 43px; height: 23px;">&nbsp;{april}</td>
<td style="width: 43px; height: 23px;">&nbsp;{may}</td>
<td style="width: 15px; height: 23px;">&nbsp;{june}</td>
<td style="width: 15px; height: 23px;">{july}&nbsp;</td>
<td style="width: 15px; height: 23px;">{august}&nbsp;</td>
<td style="width: 15px; height: 23px;">{september}&nbsp;</td>
<td style="width: 15px; height: 23px;">{october}&nbsp;</td>
<td style="width: 15px; height: 23px;">{november}</td>
<td style="width: 15px; height: 23px;">{december}</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 83px;">
<td style="width: 89px; height: 83px;">&nbsp;Number of People Born in Each&nbsp;Day</td>
<td style="width: 43px; height: 83px;">&nbsp;1</td>
<td style="width: 43px; height: 83px;">&nbsp;2</td>
<td style="width: 43px; height: 83px;">&nbsp;3</td>
<td style="width: 43px; height: 83px;">&nbsp;4</td>
<td style="width: 43px; height: 83px;">&nbsp;5</td>
<td style="width: 15px; height: 83px;">6&nbsp;</td>
<td style="width: 15px; height: 83px;">7&nbsp;</td>
<td style="width: 15px; height: 83px;">8&nbsp;</td>
<td style="width: 15px; height: 83px;">9&nbsp;</td>
<td style="width: 15px; height: 83px;">10&nbsp;</td>
<td style="width: 15px; height: 83px;">11</td>
<td style="width: 15px; height: 83px;">12</td>
<td style="width: 15px; height: 83px;">13</td>
<td style="width: 15px; height: 83px;">14</td>
<td style="width: 15px; height: 83px;">15</td>
<td style="width: 15px; height: 83px;">16</td>
<td style="width: 15px; height: 83px;">17</td>
<td style="width: 15px; height: 83px;">18</td>
<td style="width: 15px; height: 83px;">19</td>
<td style="width: 15px; height: 83px;">20</td>
<td style="width: 15px; height: 83px;">21</td>
<td style="width: 15px; height: 83px;">22</td>
<td style="width: 15px; height: 83px;">23</td>
<td style="width: 15px; height: 83px;">24</td>
<td style="width: 15px; height: 83px;">25</td>
<td style="width: 15px; height: 83px;">26</td>
<td style="width: 15px; height: 83px;">27</td>
<td style="width: 15px; height: 83px;">28&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;{d1}</td>
<td style="width: 43px; height: 23px;">{d2}&nbsp;</td>
<td style="width: 43px; height: 23px;">{d3}&nbsp;</td>
<td style="width: 43px; height: 23px;">{d4}&nbsp;</td>
<td style="width: 43px; height: 23px;">{d5}</td>
<td style="width: 15px; height: 23px;">{d6}&nbsp;</td>
<td style="width: 15px; height: 23px;">{d7}&nbsp;</td>
<td style="width: 15px; height: 23px;">{d8}&nbsp;</td>
<td style="width: 15px; height: 23px;">{d9}&nbsp;</td>
<td style="width: 15px; height: 23px;">{d10}&nbsp;</td>
<td style="width: 15px; height: 23px;">{d11}</td>
<td style="width: 15px; height: 23px;">{d12}</td>
<td style="width: 15px; height: 23px;">{d13}</td>
<td style="width: 15px; height: 23px;">{d14}</td>
<td style="width: 15px; height: 23px;">{d15}</td>
<td style="width: 15px; height: 23px;">{d16}</td>
<td style="width: 15px; height: 23px;">{d17}</td>
<td style="width: 15px; height: 23px;">{d18}</td>
<td style="width: 15px; height: 23px;">{d19}</td>
<td style="width: 15px; height: 23px;">{d20}</td>
<td style="width: 15px; height: 23px;">{d21}</td>
<td style="width: 15px; height: 23px;">{d22}</td>
<td style="width: 15px; height: 23px;">{d23}</td>
<td style="width: 15px; height: 23px;">{d24}</td>
<td style="width: 15px; height: 23px;">{d25}</td>
<td style="width: 15px; height: 23px;">{d26}</td>
<td style="width: 15px; height: 23px;">{d27}</td>
<td style="width: 15px; height: 23px;">{d28}&nbsp;</td>
</tr>
<tr style="height: 83px;">
<td style="width: 89px; height: 83px;">&nbsp;Number of People Born in Each&nbsp;Year</td>
<td style="width: 43px; height: 83px;">&nbsp;1997</td>
<td style="width: 43px; height: 83px;">1998&nbsp;</td>
<td style="width: 43px; height: 83px;">1999&nbsp;</td>
<td style="width: 43px; height: 83px;">2000&nbsp;</td>
<td style="width: 43px; height: 83px;">2001&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;{y1997}</td>
<td style="width: 43px; height: 23px;">{y1998}&nbsp;</td>
<td style="width: 43px; height: 23px;">{y1999}&nbsp;</td>
<td style="width: 43px; height: 23px;">{y2000}&nbsp;</td>
<td style="width: 43px; height: 23px;">{y2001}&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 83px;">
<td style="width: 89px; height: 83px;">&nbsp;Number of People in Each Course</td>
<td style="width: 43px; height: 83px;">&nbsp;BS Legal Management</td>
<td style="width: 43px; height: 83px;">&nbsp;BS Information Technology&nbsp;Entrepreneurship</td>
<td style="width: 43px; height: 83px;">BS Managemennt</td>
<td style="width: 43px; height: 83px;">&nbsp;BS Communications Technology</td>
<td style="width: 43px; height: 83px;">&nbsp;BS Management Engineering</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
<td style="width: 15px; height: 83px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;{lm}</td>
<td style="width: 43px; height: 23px;">{ite}&nbsp;</td>
<td style="width: 43px; height: 23px;">{mgt}&nbsp;</td>
<td style="width: 43px; height: 23px;">{ctm}&nbsp;</td>
<td style="width: 43px; height: 23px;">{me}&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;Number of People Using a Certain Carrier</td>
<td style="width: 43px; height: 23px;">&nbsp;Globe</td>
<td style="width: 43px; height: 23px;">&nbsp;Smart</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">{globe}</td>
<td style="width: 43px; height: 23px;">{smart}</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">Globe Users</td>
<td style="width: 43px; height: 23px;">Female</td>
<td style="width: 43px; height: 23px;">Male</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">{Fglobe}</td>
<td style="width: 43px; height: 23px;">{Mglobe}</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">Smart Users</td>
<td style="width: 43px; height: 23px;">Female</td>
<td style="width: 43px; height: 23px;">Male</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
<tr style="height: 23px;">
<td style="width: 89px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">{Fsmart}&nbsp;</td>
<td style="width: 43px; height: 23px;">{Msmart}&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 43px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
<td style="width: 15px; height: 23px;">&nbsp;</td>
</tr>
</tbody>
</table>
"""


html_output = html.format(january=january,
                          february = february,
                          march = march,  
                          april = april,
                          may = may, 
                          june = june,
                          july = july,
                          august = august,
                          september = september,
                          october = october,
                          november = november,
                          december = december,
                          d1 = d1,
                          d2 = d2,
                          d3 = d3,
                          d4 = d4,
                          d5 = d5,
                          d6 = d6,
                          d7 = d7,
                          d8 = d8,
                          d9 = d9,
                          d10 = d10,
                          d11 = d11, 
                          d12 = d12,
                          d13 = d13,
                          d14 = d14,
                          d15 = d15,
                          d16 = d16,
                          d17 = d17,
                          d18 = d18,
                          d19 = d19,
                          d20 = d20,
                          d21 = d21, 
                          d22 = d22, 
                          d23 = d23,
                          d24 = d24, 
                          d25 = d25,
                          d26 = d26, 
                          d27 = d27,
                          d28 = d28,
                          y1997 = y1997,
                          y1998 = y1998,
                          y1999 = y1999,
                          y2000 = y2000,
                          y2001 = y2001,
                          ctm = ctm,
                          ite = ite,
                          lm = lm,
                          mgt = mgt,
                          me = me,
                          globe = int(carriergendercount[('Male','Globe')]) + int(carriergendercount[('Female','Globe')]),
                          smart = int(carriergendercount[('Male','Smart')]) + int(carriergendercount[('Female','Smart')]),
                          Mglobe = Mglobe,
                          Fglobe = Fglobe,
                          Msmart = Msmart,
                          Fsmart = Fsmart
                          ) 
                          
HTML(html_output)

with open('stats3b.html',"w") as file:
    file.write(html_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-91617c4479f4> in <module>
#     444
#     445
# --> 446 html_output = html.format(january=january,
#     447                           february = february,
#     448                           march = march,
#
# NameError: name 'january' is not defined
